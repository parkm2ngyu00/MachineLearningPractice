# %%
# !pip install ipywidgets  # for vscode
# !pip install git+https://git@github.com/SKTBrain/KoBERT.git@master

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import gluonnlp as nlp
import numpy as np
from tqdm.notebook import tqdm

# %%
from kobert import get_tokenizer
from kobert import get_pytorch_kobert_model

# %%
from transformers import AdamW
from transformers.optimization import get_cosine_schedule_with_warmup

# %%
## CPU
device = torch.device("cpu")

## GPU
# device = torch.device("cuda:0")

# %%
bertmodel, vocab = get_pytorch_kobert_model(cachedir=".cache")
# Out:
# /content/.cache/kobert_v1.zip[██████████████████████████████████████████████████]
# /content/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece[██████████████████████████████████████████████████]

# %%
# !wget -O .cache/ratings_train.txt http://skt-lsl-nlp-model.s3.amazonaws.com/KoBERT/datasets/nsmc/ratings_train.txt
# !wget -O .cache/ratings_test.txt http://skt-lsl-nlp-model.s3.amazonaws.com/KoBERT/datasets/nsmc/ratings_test.txt
# Out:
# --2022-08-08 08:05:04--  http://skt-lsl-nlp-model.s3.amazonaws.com/KoBERT/datasets/nsmc/ratings_train.txt
# Resolving skt-lsl-nlp-model.s3.amazonaws.com (skt-lsl-nlp-model.s3.amazonaws.com)... 52.219.148.14
# Connecting to skt-lsl-nlp-model.s3.amazonaws.com (skt-lsl-nlp-model.s3.amazonaws.com)|52.219.148.14|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14628807 (14M) [text/plain]
# Saving to: ‘.cache/ratings_train.txt’
#
# .cache/ratings_trai 100%[===================>]  13.95M  5.02MB/s    in 2.8s
#
# 2022-08-08 08:05:08 (5.02 MB/s) - ‘.cache/ratings_train.txt’ saved [14628807/14628807]
#
# --2022-08-08 08:05:08--  http://skt-lsl-nlp-model.s3.amazonaws.com/KoBERT/datasets/nsmc/ratings_test.txt
# Resolving skt-lsl-nlp-model.s3.amazonaws.com (skt-lsl-nlp-model.s3.amazonaws.com)... 52.219.58.86
# Connecting to skt-lsl-nlp-model.s3.amazonaws.com (skt-lsl-nlp-model.s3.amazonaws.com)|52.219.58.86|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4893335 (4.7M) [text/plain]
# Saving to: ‘.cache/ratings_test.txt’
#
# .cache/ratings_test 100%[===================>]   4.67M  2.30MB/s    in 2.0s
#
# 2022-08-08 08:05:10 (2.30 MB/s) - ‘.cache/ratings_test.txt’ saved [4893335/4893335]

# %%
dataset_train = nlp.data.TSVDataset(".cache/ratings_train.txt", field_indices=[1,2], num_discard_samples=1)
dataset_test = nlp.data.TSVDataset(".cache/ratings_test.txt", field_indices=[1,2], num_discard_samples=1)

# %%
tokenizer = get_tokenizer()
tok = nlp.data.BERTSPTokenizer(tokenizer, vocab, lower=False)
# Out:
# using cached model. /content/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece

# %%
class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len,
                 pad, pair):
        transform = nlp.data.BERTSentenceTransform(
            bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair)

        self.sentences = [transform([i[sent_idx]]) for i in dataset]
        self.labels = [np.int32(i[label_idx]) for i in dataset]

    def __getitem__(self, i):
        return (self.sentences[i] + (self.labels[i], ))

    def __len__(self):
        return (len(self.labels))

# %%
## Setting parameters
max_len = 64
batch_size = 64
warmup_ratio = 0.1
num_epochs = 5
max_grad_norm = 1
log_interval = 200
learning_rate =  5e-5

# %%
data_train = BERTDataset(dataset_train, 0, 1, tok, max_len, True, False)
data_test = BERTDataset(dataset_test, 0, 1, tok, max_len, True, False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-bca58955ac96> in <module>()
# ----> 1 data_train = BERTDataset(dataset_train, 0, 1, tok, max_len, True, False)
#       2 data_test = BERTDataset(dataset_test, 0, 1, tok, max_len, True, False)
#
# <ipython-input-10-a9b1e492c2b1> in __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len, pad, pair)
#       5             bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair)
#       6
# ----> 7         self.sentences = [transform([i[sent_idx]]) for i in dataset]
#       8         self.labels = [np.int32(i[label_idx]) for i in dataset]
#       9
#
# <ipython-input-10-a9b1e492c2b1> in <listcomp>(.0)
#       5             bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair)
#       6
# ----> 7         self.sentences = [transform([i[sent_idx]]) for i in dataset]
#       8         self.labels = [np.int32(i[label_idx]) for i in dataset]
#       9
#
# /usr/local/lib/python3.7/dist-packages/gluonnlp/data/transforms.py in __call__(self, line)
#    1011             text_b = line[1]
#    1012
# -> 1013         tokens_a = self._tokenizer(text_a)
#    1014         tokens_b = None
#    1015
#
# /usr/local/lib/python3.7/dist-packages/gluonnlp/data/transforms.py in __call__(self, sample)
#     847         """
#     848
# --> 849         return self._tokenizer(sample)
#     850
#     851     def _tokenizer(self, text):
#
# /usr/local/lib/python3.7/dist-packages/gluonnlp/data/transforms.py in _tokenizer(self, text)
#     852         split_tokens = []
#     853         for token in self.basic_tokenizer(text):
# --> 854             for sub_token in self._tokenize_wordpiece(token):
#     855                 split_tokens.append(sub_token)
#     856
#
# /usr/local/lib/python3.7/dist-packages/gluonnlp/data/transforms.py in _tokenize_wordpiece(self, text)
#     876         if self.sentencepiece is None:
#     877             self._activate_sp()
# --> 878         output_tokens = self.sentencepiece(text)
#     879         return output_tokens
#     880
#
# /usr/local/lib/python3.7/dist-packages/gluonnlp/data/transforms.py in __call__(self, sample)
#     559         """
#     560         return self._processor.SampleEncodeAsPieces(sample, self._nbest,
# --> 561                                                     self._alpha)
#     562
#     563
#
# /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py in SampleEncodeAsPieces(self, input, nbest_size, alpha, **kwargs)
#     560     def SampleEncodeAsPieces(self, input, nbest_size=None, alpha=None, **kwargs):
#     561       return self.Encode(input=input, nbest_size=nbest_size, alpha=alpha,
# --> 562                          out_type=str, enable_sampling=True, **kwargs)
#     563
#     564
#
# /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py in Encode(self, input, out_type, add_bos, add_eos, reverse, emit_unk_piece, enable_sampling, nbest_size, alpha, num_threads)
#     502                                       nbest_size == 1 or alpha is None):
#     503         raise RuntimeError(
# --> 504             'When enable_sampling is True, We must specify "nbest_size > 1" or "nbest_size = -1", '
#     505             'and "alpha". "nbest_size" is enabled only on unigram mode ignored in BPE-dropout. '
#     506             'when "nbest_size = -1" , this method samples from all candidates on the lattice '
#
# RuntimeError: When enable_sampling is True, We must specify "nbest_size > 1" or "nbest_size = -1", and "alpha". "nbest_size" is enabled only on unigram mode ignored in BPE-dropout. when "nbest_size = -1" , this method samples from all candidates on the lattice instead of nbest segmentations.
