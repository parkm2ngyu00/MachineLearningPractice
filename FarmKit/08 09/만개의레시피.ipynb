# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MachineLearningPractice/Colab-Notebooks/FarmKit/foodfile/만개의레시피.csv')
df = df.dropna()
df.shape
# Out:
# (2343, 7)

# %%
df.reset_index(inplace=True)
df.drop(['index', 'id'], inplace=True, axis=1)
df.rename(columns={'설명':'description'}, inplace=True)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   카테고리명  분류기준       식품명                                        description  \
# 0    양식  그라탕류   라따뚜이그라탕  It is a gratin using ratatouille, a traditiona...
# 1    간식  토스트류    햄치즈토스트  Sliced ​​ham and cheese are placed on bread an...
# 2   밑반찬  건어물류    마른미역자반  It is a side dish of dried seaweed fried in oi...
# 3    한식   찌개류  돼지고기된장찌개  It is a stew made by slicing pork and putting ...
# 4    간식    빵류    고구마치즈빵  A sweet-tasting bread topped with boiled sweet...
#
#                                                ingre  \
# 0  Tomato, eggplant, zucchini, penne, tomato sauc...
# 1  White bread, sliced ​​ham, cheddar cheese, can...
# 2  Dried seaweed, perilla oil, cooking oil, sugar...
# 3  Pork leg meat, green onion, onion, zucchini, r...
# 4  Steamed sweet potato, mayonnaise, honey, mozza...
#
#                                               recipe
# 0  Prepare tomatoes, eggplant, and zucchini by cu...
# 1  Prepare the cabbage and carrots by slicing the...
# 2  Heat perilla oil and cooking oil in a pan. Whe...
# 3  Cut the onion and pumpkin into appropriate siz...
# 4  Mix flour, milk, melted butter and salt in a b...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix_description = tfidf.fit_transform(df['description'])
tfidf_matrix_ingre = tfidf.fit_transform(df['ingre'])
tfidf_matrix_recipe = tfidf.fit_transform(df['recipe'])

# %%
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

cosine_sim_description = cosine_similarity(tfidf_matrix_description, tfidf_matrix_description)
cosine_sim_ingre = cosine_similarity(tfidf_matrix_ingre, tfidf_matrix_ingre)
cosine_sim_recipe = cosine_similarity(tfidf_matrix_recipe, tfidf_matrix_recipe)
distance_sim_description = euclidean_distances(tfidf_matrix_description, tfidf_matrix_description)
distance_sim_ingre = euclidean_distances(tfidf_matrix_ingre, tfidf_matrix_ingre)
distance_sim_recipe = euclidean_distances(tfidf_matrix_recipe, tfidf_matrix_recipe)

# %%
indices = pd.Series(df.index, index=df['식품명']).drop_duplicates()
# 음식명을 입력받으면 코사인 유사도를 통해서 가장 유사도가 높은 상위 10개의 음식 목록 반환
def get_recommendations(title, sim, reverse):
  
  # 음식명을 통해서 전체 데이터 기준 그 음식의 index 값을 얻기
  idx = indices[title]

  # 유사도 매트릭스 에서 idx 에 해당하는 데이터를 (idx, 유사도) 형태로 얻기
  sim_scores = list(enumerate(sim[idx]))

  # 유사도 기준 정렬
  sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=reverse)    # 코사인 유사도는 True, 유클리디안 유사도는 False를 넣어줘야함

  # 자기 자신을 제외한 10개의 추천 음식을 슬라이싱
  sim_scores = sim_scores[1:11]

  # 추천 음식목록 10개의 인덱스 정보 추출
  movie_indices = [i[0] for i in sim_scores]

  # 인덱스 정보를 통해 음식명 추출
  return list(df['식품명'].iloc[movie_indices])

# %%
def to_dataframe (cos_description, euc_description, cos_ingre, euc_ingre, cos_recipe, euc_recipe):
    df = pd.DataFrame()
    df['cos description'] = cos_description
    df['euc description'] = euc_description
    df['cos ingre'] = cos_ingre
    df['euc ingre'] = euc_ingre
    df['cos recipe'] = cos_recipe
    df['euc recipe'] = euc_recipe
    return df

# %%
to_dataframe(get_recommendations('고구마치즈빵', cosine_sim_description, True), get_recommendations('고구마치즈빵', distance_sim_description, False), get_recommendations('고구마치즈빵', cosine_sim_ingre, True), get_recommendations('고구마치즈빵', distance_sim_ingre, False), get_recommendations('고구마치즈빵', cosine_sim_recipe, True), get_recommendations('고구마치즈빵', distance_sim_recipe, False))
# Out:
#   cos description euc description   cos ingre   euc ingre   cos recipe  \
# 0         더블치즈토스트              부각    아코디언꿀고구마    아코디언꿀고구마  제티체크쿠키&제티설기
# 1           치즈마늘빵         더블치즈토스트     로즈연유브레드     로즈연유브레드         감자피자
# 2        베이컨치즈토스트           치즈마늘빵       콘치즈와플       콘치즈와플          소금빵
# 3            프로틴빵        베이컨치즈토스트       하이토스트       하이토스트          공갈빵
# 4             구름빵            프로틴빵         소금빵         소금빵     고구마베이컨말이
# 5   리얼고구마빵&리얼 감자빵             구름빵         모닝빵         모닝빵        참깨크래커
# 6           하이토스트   리얼고구마빵&리얼 감자빵     더블치즈토스트     더블치즈토스트         시나몬롤
# 7           크림통식빵           하이토스트  떠먹는 고구마케이크  떠먹는 고구마케이크          모닝빵
# 8          고구마치즈볼           크림통식빵      고구마치즈볼      고구마치즈볼       감자찹쌀구이
# 9     몬테크리스토 샌드위치          고구마치즈볼       땅콩러스크       땅콩러스크         사과파이
#
#     euc recipe
# 0  제티체크쿠키&제티설기
# 1         감자피자
# 2          소금빵
# 3          공갈빵
# 4     고구마베이컨말이
# 5        참깨크래커
# 6         시나몬롤
# 7          모닝빵
# 8       감자찹쌀구이
# 9         사과파이

# %%
to_dataframe(get_recommendations('돼지고기된장찌개', cosine_sim_description, True), get_recommendations('돼지고기된장찌개', distance_sim_description, False), get_recommendations('돼지고기된장찌개', cosine_sim_ingre, True), get_recommendations('돼지고기된장찌개', distance_sim_ingre, False), get_recommendations('돼지고기된장찌개', cosine_sim_recipe, True), get_recommendations('돼지고기된장찌개', distance_sim_recipe, False))
# Out:
#   cos description euc description  cos ingre  euc ingre       cos recipe  \
# 0            짜글이장              부각  돼지고기애호박찌개  돼지고기애호박찌개           삼겹두부조림
# 1             무채전            짜글이장       달걀마파       달걀마파           닭갈비떡볶이
# 2        돼지고기김치찌개             무채전       돼지불백       돼지불백  마파두부, 깐풍기, 짜장육사
# 3       돼지고기애호박찌개        돼지고기김치찌개      닭맥적구이      닭맥적구이             마파두부
# 4            갓돈찌개       돼지고기애호박찌개       두부조림       두부조림          돼지고기무조림
# 5        돼지고기김치찌개            갓돈찌개     마파달걀덮밥     마파달걀덮밥           차돌된장찌개
# 6           베이컨솥밥        돼지고기김치찌개     차돌된장찌개     차돌된장찌개            빨간무덮밥
# 7            연어솥밥           베이컨솥밥        톳무침        톳무침            짜장떡볶이
# 8        돼지고기채소스튜            연어솥밥     닭갈비떡볶이     닭갈비떡볶이             두부잡채
# 9            함박스튜        돼지고기채소스튜       마파두부       마파두부             두부조림
#
#         euc recipe
# 0           삼겹두부조림
# 1           닭갈비떡볶이
# 2  마파두부, 깐풍기, 짜장육사
# 3             마파두부
# 4          돼지고기무조림
# 5           차돌된장찌개
# 6            빨간무덮밥
# 7            짜장떡볶이
# 8             두부잡채
# 9             두부조림

# %%
to_dataframe(get_recommendations('두부잡채', cosine_sim_description, True), get_recommendations('두부잡채', distance_sim_description, False), get_recommendations('두부잡채', cosine_sim_ingre, True), get_recommendations('두부잡채', distance_sim_ingre, False), get_recommendations('두부잡채', cosine_sim_recipe, True), get_recommendations('두부잡채', distance_sim_recipe, False))
# Out:
#   cos description euc description cos ingre euc ingre  cos recipe  euc recipe
# 0          가을채소잡채              부각      두부깐풍      두부깐풍        두부깐풍        두부깐풍
# 1            두부김밥          가을채소잡채     버섯떡잡채     버섯떡잡채      두부스팸강정      두부스팸강정
# 2           된장리조또            두부김밥      해물잡채      해물잡채  두부구이와 양념간장  두부구이와 양념간장
# 3             두부밥           된장리조또   비프 레터스랩   비프 레터스랩       두부고로케       두부고로케
# 4        닭가슴살채소덮밥             두부밥     찹스테이크     찹스테이크     버섯두부피망찜     버섯두부피망찜
# 5       라이스페이퍼떡볶이        닭가슴살채소덮밥      닭불고기      닭불고기       새우유부밥       새우유부밥
# 6           샐러드김밥       라이스페이퍼떡볶이   소세지야채볶음   소세지야채볶음       포두부냉채       포두부냉채
# 7         소고기당면찌개           샐러드김밥     피자토스트     피자토스트         두부밥         두부밥
# 8           버섯떡잡채         소고기당면찌개  큐브 스테이크동  큐브 스테이크동        두부피자        두부피자
# 9           양배추잡채           버섯떡잡채    가을채소잡채    가을채소잡채        해물잡채        해물잡채

# %%
# !pip install transformers
import torch
from transformers import AutoModel, AutoTokenizer

MODEL_NAME = "bert-base-multilingual-cased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 5.2 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 21.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 73.7 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 13.1 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 tokenizers-0.12.1 transformers-4.21.1
# Downloading tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/972k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.87M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/681M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# [CLS] token을 얻기 위한 함수
def get_cls_token(sent_A):
    model.eval()
    tokenized_sent = tokenizer(
            sent_A,
            return_tensors="pt",
            truncation=True,
            add_special_tokens=True,
            max_length=128
    )
    with torch.no_grad():# 그라디엔트 계산 비활성화
        outputs = model(    # **tokenized_sent
            input_ids=tokenized_sent['input_ids'],
            attention_mask=tokenized_sent['attention_mask'],
            token_type_ids=tokenized_sent['token_type_ids']
            )
    logits = outputs.last_hidden_state[:,0,:].detach().cpu().numpy()
    return logits

# %%
def cls_token_array(df, column) :
  dataset_cls_hidden = []
  for i in range(df.shape[0]):
      q_cls = get_cls_token(str(df.loc[i, column])) #column 예: '음식설명', '영문'
      dataset_cls_hidden.append(q_cls)
  dataset_cls_hidden = np.array(dataset_cls_hidden).squeeze(axis=1)
  #print(dataset_cls_hidden)   
  print(dataset_cls_hidden.shape) # column에 대한 [CLS] 토큰 벡터
  return dataset_cls_hidden

column = 'description'
dataset_cls_hidden = cls_token_array(df, column)
# Out:
# (2343, 768)

# %%
def bert_food_recommendation(df, dataset_cls_hidden, column, food, similarity): 
  
  index = df[df['식품명'] == food].index[0]
  food_cls_hidden = get_cls_token(str(df.loc[index, column]))

  sim = similarity(food_cls_hidden, dataset_cls_hidden)
  #print(cos_sim)
  if similarity == cosine_similarity:
    top = np.argpartition(sim, -10)[:, -10:] # 상위 10개 인덱스 추출
  else :
    top = np.argpartition(sim, 10)[:, :10]

  return list(df.iloc[top[0]]['식품명'])

# %%
def to_dataframe2 (cos_description, euc_description, cos_ingre, euc_ingre, cos_recipe, euc_recipe):
    df = pd.DataFrame()
    df['cos description'] = cos_description
    df['euc description'] = euc_description
    df['cos ingre'] = cos_ingre
    df['euc ingre'] = euc_ingre
    df['cos recipe'] = cos_recipe
    df['euc recipe'] = euc_recipe
    return df

# %%
to_dataframe2(bert_food_recommendation(df, dataset_cls_hidden, 'description', '고구마치즈빵', cosine_similarity), bert_food_recommendation(df, dataset_cls_hidden, 'description', '고구마치즈빵', euclidean_distances), bert_food_recommendation(df, dataset_cls_hidden, 'ingre', '고구마치즈빵', cosine_similarity), bert_food_recommendation(df, dataset_cls_hidden, 'ingre', '고구마치즈빵', euclidean_distances), bert_food_recommendation(df, dataset_cls_hidden, 'recipe', '고구마치즈빵', cosine_similarity), bert_food_recommendation(df, dataset_cls_hidden, 'recipe', '고구마치즈빵', euclidean_distances))
# Out:
#   cos description euc description cos ingre   euc ingre     cos recipe  \
# 0       감드위치&포테딕트          고구마치즈빵     진미채무침       관자샐러드             군밤
# 1          레몬머랭파이           크로크마담  치즈베이컨그라탕       누들샐러드         된장가지구이
# 2           갸또쇼콜라          옥수수케이크  오징어볶음&소면       땅콩러스크       쉬폰파운드케이크
# 3  달콤하지롤&레몬너한테피치나  달콤하지롤&레몬너한테피치나      불낙볶음    오징어볶음&소면           구겔호프
# 4         리스샐러드피자           갸또쇼콜라     관자샐러드      연어치즈말이         봉골레수제비
# 5           꿀땅콩스낵         리스샐러드피자    토마토처트니        불낙볶음  스파이더맨고추장참치볶음밥
# 6          옥수수케이크            감귤샌드    연어치즈말이     베이컨감자구이        명란감자채볶음
# 7         카프레제샐러드           꿀땅콩스낵     만능볶음밥       만능볶음밥         찹쌀치즈어묵
# 8          고구마치즈빵       감드위치&포테딕트     땅콩러스크    막창국수&달걀찜           달걀버거
# 9           크로크마담          레몬머랭파이     누들샐러드  구운가지토마토샐러드      구운명란치즈주먹밥
#
#       euc recipe
# 0           구겔호프
# 1        명란감자채볶음
# 2           달걀버거
# 3         찹쌀치즈어묵
# 4  스파이더맨고추장참치볶음밥
# 5         봉골레수제비
# 6       쉬폰파운드케이크
# 7      구운명란치즈주먹밥
# 8            무스비
# 9            밤양갱

# %%
to_dataframe2(bert_food_recommendation(df, dataset_cls_hidden, 'description', '돼지고기김치찌개', cosine_similarity), bert_food_recommendation(df, dataset_cls_hidden, 'description', '돼지고기김치찌개', euclidean_distances), bert_food_recommendation(df, dataset_cls_hidden, 'ingre', '돼지고기김치찌개', cosine_similarity), bert_food_recommendation(df, dataset_cls_hidden, 'ingre', '돼지고기김치찌개', euclidean_distances), bert_food_recommendation(df, dataset_cls_hidden, 'recipe', '돼지고기김치찌개', cosine_similarity), bert_food_recommendation(df, dataset_cls_hidden, 'recipe', '돼지고기김치찌개', euclidean_distances))
# Out:
#   cos description euc description   cos ingre  euc ingre     cos recipe  \
# 0           양송이스프             김치국     소시지파피요트     달걀참치콘전            무스비
# 1            감자스프        돼지고기김치찌개    치즈베이컨그라탕         치킨       쉬폰파운드케이크
# 2          꽁치부대찌개        돼지고기김치찌개         삼두죽    소시지파피요트        명란감자채볶음
# 3             김치국            감자스프       만능볶음밥      샐러드우동           구겔호프
# 4            갓돈찌개            갓돈찌개      달걀참치콘전      ABC주스  스파이더맨고추장참치볶음밥
# 5           순두부찌개          꽁치부대찌개    버섯전골&채소죽      콩 샐러드         찹쌀치즈어묵
# 6           순두부찌개       돼지김치찌개 전골  참치마요네즈샌드위치  돼지고기순두부찌개           달걀버거
# 7       돼지김치찌개 전골           순두부찌개       ABC주스   맥도날드 콘파이         된장가지구이
# 8        돼지고기김치찌개           순두부찌개       콩 샐러드   버섯전골&채소죽         봉골레수제비
# 9        돼지고기김치찌개      망고젤리요거트스무디       샐러드우동        삼두죽      구운명란치즈주먹밥
#
#       euc recipe
# 0           달걀버거
# 1  스파이더맨고추장참치볶음밥
# 2         봉골레수제비
# 3        명란감자채볶음
# 4         된장가지구이
# 5      구운명란치즈주먹밥
# 6         찹쌀치즈어묵
# 7           구겔호프
# 8       쉬폰파운드케이크
# 9            무스비

# %%
to_dataframe2(bert_food_recommendation(df, dataset_cls_hidden, 'description', '두부잡채', cosine_similarity), bert_food_recommendation(df, dataset_cls_hidden, 'description', '두부잡채', euclidean_distances), bert_food_recommendation(df, dataset_cls_hidden, 'ingre', '두부잡채', cosine_similarity), bert_food_recommendation(df, dataset_cls_hidden, 'ingre', '두부잡채', euclidean_distances), bert_food_recommendation(df, dataset_cls_hidden, 'recipe', '두부잡채', cosine_similarity), bert_food_recommendation(df, dataset_cls_hidden, 'recipe', '두부잡채', euclidean_distances))
# Out:
#   cos description euc description    cos ingre  euc ingre     cos recipe  \
# 0        굴라면&어묵라면          가을채소잡채  원팬 새우토마토파스타      들깨삼계탕            무스비
# 1              울면      딸기마스카포네크림빵        들깨삼계탕    연두부티라미수          된장리조또
# 2            연어국수        굴라면&어묵라면      연두부티라미수      샐러드우동            육원전
# 3         바나나요거트볼            연어국수       해산물샐러드     봉골레수제비           구겔호프
# 4           죠리퐁라떼       라이스페이퍼떡볶이        콩 샐러드      바나나로띠         봉골레수제비
# 5          가을채소잡채          두부땡초김밥          육채미      콩 샐러드           달걀버거
# 6       닭안심백김치볶음밥            두부잡채       봉골레수제비        육채미      구운명란치즈주먹밥
# 7       라이스페이퍼떡볶이           죠리퐁라떼        샐러드우동      골뱅이무침  스파이더맨고추장참치볶음밥
# 8            두부잡채       닭안심백김치볶음밥        바나나로띠     해산물샐러드         된장가지구이
# 9      딸기마스카포네크림빵             감태전        골뱅이무침  고추참치짜르보나라        명란감자채볶음
#
#       euc recipe
# 0            육원전
# 1           구겔호프
# 2         된장가지구이
# 3      구운명란치즈주먹밥
# 4  스파이더맨고추장참치볶음밥
# 5        명란감자채볶음
# 6           달걀버거
# 7         봉골레수제비
# 8            밤양갱
# 9          된장리조또
