# %% [markdown]
# ### **Collaborative Filtering (협업 필터링 : 사용자 리뷰 기반)**

# %% [markdown]
# 나 : Up, 주토피아
#
# 다른 사람 : Up, 주토피아, 인사이드 아웃

# %% [markdown]
# **surprise 패키지 사용**
# **참고 자료**
# https://surprise.readthedocs.io/en/stable/getting_started.html
# https://surprise.readthedocs.io/en/stable/reader.html

# %%
# !pip install scikit-surprise
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.8 MB 7.4 MB/s
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp37-cp37m-linux_x86_64.whl size=1633735 sha256=a32127da20b3a39dec8271dabea94d656862fe9a228d685915ef1a78ce0b310d
#   Stored in directory: /root/.cache/pip/wheels/76/44/74/b498c42be47b2406bd27994e16c5188e337c657025ab400c1c
# Successfully built scikit-surprise
# ...

# %%
import surprise
surprise.__version__
# Out:
# '1.1.1'

# %%
import pandas as pd
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
ratings = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MachineLearningPractice/Colab-Notebooks/ML_movie_recommend/ratings_small.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
reader = Reader(rating_scale=(0.5, 5))    # 평점이 0.5 ~ 5점 사이

# %%
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader=reader)

# %%
svd = SVD(random_state=0)

# %%
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)   # K-Fold 교차 검증 (5세트), 진행되는 과정 설명
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8992  0.8992  0.8893  0.8984  0.8914  0.8955  0.0043
# MAE (testset)     0.6916  0.6939  0.6848  0.6891  0.6877  0.6894  0.0031
# Fit time          5.36    5.11    5.25    5.30    5.18    5.24    0.09
# Test time         0.23    0.33    0.16    0.16    0.40    0.26    0.09
# {'fit_time': (5.356341361999512,
#   5.105921030044556,
#   5.2532958984375,
#   5.299124240875244,
#   5.1839587688446045),
#  'test_mae': array([0.69163551, 0.69388886, 0.68480613, 0.68910959, 0.68769052]),
#  'test_rmse': array([0.89923388, 0.89924792, 0.8892527 , 0.89835434, 0.89136959]),
#  'test_time': (0.23376226425170898,
#   0.3264009952545166,
#   0.15705633163452148,
#   0.16392850875854492,
#   0.39891791343688965)}

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)     # 학습 진행

# %%
ratings[ratings['userId'] == 1]
# Out:
#     userId  movieId  rating   timestamp
# 0        1       31     2.5  1260759144
# 1        1     1029     3.0  1260759179
# 2        1     1061     3.0  1260759182
# 3        1     1129     2.0  1260759185
# 4        1     1172     4.0  1260759205
# 5        1     1263     2.0  1260759151
# 6        1     1287     2.0  1260759187
# 7        1     1293     2.0  1260759148
# 8        1     1339     3.5  1260759125
# 9        1     1343     2.0  1260759131
# 10       1     1371     2.5  1260759135
# 11       1     1405     1.0  1260759203
# 12       1     1953     4.0  1260759191
# 13       1     2105     4.0  1260759139
# 14       1     2150     3.0  1260759194
# 15       1     2193     2.0  1260759198
# 16       1     2294     2.0  1260759108
# 17       1     2455     2.5  1260759113
# 18       1     2968     1.0  1260759200
# 19       1     3671     3.0  1260759117

# %%
svd.predict(1, 302)
# Out:
# Prediction(uid=1, iid=302, r_ui=None, est=2.7142061734434044, details={'was_impossible': False})

# %%
svd.predict(1, 1029)    #UserId 1번인 사람이 movieId 1029 인 영하에 대하여 실제 평가 3점일 때, 예측 평가 점수?
# Out:
# Prediction(uid=1, iid=1029, r_ui=None, est=2.8814455446761933, details={'was_impossible': False})

# %%
ratings[ratings['userId'] == 100]
# Out:
#        userId  movieId  rating  timestamp
# 15273     100        1     4.0  854193977
# 15274     100        3     4.0  854194024
# 15275     100        6     3.0  854194023
# 15276     100        7     3.0  854194024
# 15277     100       25     4.0  854193977
# 15278     100       32     5.0  854193977
# 15279     100       52     3.0  854194056
# 15280     100       62     3.0  854193977
# 15281     100       86     3.0  854194208
# 15282     100       88     2.0  854194208
# 15283     100       95     3.0  854193977
# 15284     100      135     3.0  854194086
# 15285     100      141     3.0  854193977
# 15286     100      608     4.0  854194024
# 15287     100      648     3.0  854193977
# 15288     100      661     3.0  854194086
# 15289     100      708     3.0  854194056
# 15290     100      733     3.0  854194024
# 15291     100      736     3.0  854193977
# 15292     100      745     4.0  854194208
# 15293     100      780     3.0  854193977
# ...

# %%
svd.predict(100, 1029)
# Out:
# Prediction(uid=100, iid=1029, r_ui=None, est=3.7705476478414846, details={'was_impossible': False})
